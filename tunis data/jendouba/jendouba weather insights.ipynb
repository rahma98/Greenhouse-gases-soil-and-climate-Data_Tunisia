# %% [markdown]
# # I. Soil Properties

# %%
import pandas as pd 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('soil data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   YEAR      90 non-null     int64
#  1   DOY       90 non-null     int64
#  2   GWETTOP   90 non-null     float64
#  3   GWETROOT  90 non-null     float64
#  4   GWETPROF  90 non-null     float64
# dtypes: float64(3), int64(2)
# memory usage: 3.6 KB

# %%
data.head(5)
# Out:
#    YEAR  DOY  GWETTOP  GWETROOT  GWETPROF
# 0  2021    1     0.59      0.59       0.6
# 1  2021    2     0.59      0.58       0.6
# 2  2021    3     0.59      0.58       0.6
# 3  2021    4     0.59      0.58       0.6
# 4  2021    5     0.59      0.57       0.6

# %%
df = pd.DataFrame(data)

# Specify columns for the bar chart
columns_to_plot = ['GWETTOP', 'GWETROOT', 'GWETPROF']

# Subset the DataFrame to include only the specified columns
subset_df = df[columns_to_plot]

# %%
# Plotting the line graph
plt.figure(figsize=(12, 8))
for column in columns_to_plot:
    plt.plot(df['DOY'], df[column], label=column)

plt.title('Soil Properties Data')
plt.xlabel('Day of Year 2021')
plt.ylabel('propabilities in  Jendouba')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.legend(title='Columns', bbox_to_anchor=(1.05, 1), loc='upper left')  # Add legend with column names as titles
plt.grid(True, linestyle='--', alpha=0.7)  # Add grid lines
plt.show()

# %% [markdown]
# ## Details about Data

# %% [markdown]
#  -  **Resource**:
# NASA/POWER CERES/MERRA2 Native Resolution Daily Dat.
#  -  **Dates (month/day/year)**: 01/01/2021 through 03/31/2021.
#  -    **Location**: Latitude 36.5   Longitude 9.0
#  -    **Elevation from MERRA-2:** Average for 0.5 x 0.625 degree lat/lon region = 352.32 meters
#  -    **The value for missing source data** that cannot be computed or is outside of the sources availability range: -999.ND HEADER-

# %% [markdown]
# ## Parameters:

# %% [markdown]
# - **GWETTOP :**     MERRA-2 Surface Soil Wetness
# - **GWETROOT :**    MERRA-2 Root Zone Soil Wetness
# -  **GWETPROF :**    MERRA-2 Profile Soil Moisture

# %% [markdown]
# ## Insight:

# %% [markdown]
# 1. **GWETTOP (MERRA-2 Surface Soil Wetness)** :
#    - Un niveau critique pour la surface du sol peut être considéré comme inférieur à environ 20 % d'humidité du sol.
#    - Les valeurs inférieures à ce seuil peuvent indiquer un sol sec, peu propice à la croissance des cultures sans irrigation supplémentaire.
#
# 2. **GWETROOT (MERRA-2 Root Zone Soil Wetness)** :
#    - Pour la zone racinaire du sol, un seuil critique pourrait être autour de 40 % à 50 % d'humidité du sol.
#    - Des valeurs inférieures à ce seuil pourraient indiquer un stress hydrique pour les plantes, affectant leur capacité à absorber l'eau nécessaire.
#
# 3. **GWETPROF (MERRA-2 Profile Soil Moisture)** :
#    - Pour l'humidité sur toute la profondeur du profil du sol, un seuil critique pourrait être autour de 30 % à 40 % d'humidité du sol.
#    - Des valeurs inférieures à ce seuil peuvent indiquer un sol excessivement sec, affectant la disponibilité en eau pour les racines oduction agricole.

# %% [markdown]
# Les valeurs du GWETPROF (MERRA-2 Profile Soil Moisture) et du GWETROOT (MERRA-2 Root Zone Soil Wetness) se situent entre 28 % et 25 %, cela peut indiquer des conditions de sol relativement sèches.
#
# 1. **Conditions de Stress Hydrique** :
#    - Des valeurs de GWETPROF et GWETROOT entre 28 % et 25 % suggèrent que le sol peut être en situation de stress hydrique modéré à sévère.
#    - Les plantes peuvent avoir des difficultés à accéder à suffisamment d'eau pour maintenir leur croissance normale et leur développement racinaire.
#
# 2. **Besoin d'Irrigation** :
#    - Dans ces conditions, il peut être nécessaire d'irriguer les cultures pour compenser le manque d'eau dans le sol.
#    - L'irrigation peut aider à maintenir des niveaux d'humidité du sol plus favorables pour les plantes et à soutenir la croissance des cultures.
#
# 3. **Risque de Déficit Hydrique** :
#    - Des valeurs inférieures à 30 % dans le GWETPROF et le GWETROOT indiquent un risque accru de déficit hydrique, ce qui peut affecter la productivité des cultures et la qualité des sols.
#
# 4. **Impact sur les Réserves d'Eau** :
#    - Des valeurs comprises entre 28 % et 25 % dans le GWETPROF et le GWETROOT peuvent indiquer une diminution des réserves d'eau disponibles dans le sol, ce qui peut avoir un impact sur la disponibilité en eau pour les cultures et leses sur le terrain.on agricole.

# %% [markdown]
# # II. Climate:

# %% [markdown]
# **info about the Data**
#  - Dates (month/day/year): 01/01/1990 through 04/27/2024.
#  - Location: Latitude  36.5011   Longitude 8.7802
#  - Elevation from MERRA-2: Average for 0.5 x 0.625 degree lat/lon region = 352.32 meters
#  - The value for missing source data that cannot be computed or is outside of the sources availability range:-999.
# ers
#
#
#
# **Parameters:**
#
# - T2M             MERRA-2 Temperature at 2 Me
# - T2MDEW          MERRA-2 Dew/Frost Point at 2 Meters (C)
# - T2MWET          MERRA-2 Wet Bulb Temperature at 2 Meters (C)
# - TS              MERRA-2 Earth Skin Temperature (C)
# - T2M_RANGE       MERRA-2 Temperature at 2 Meters Range (C)
# - T2M_MAX         MERRA-2 Temperature at 2 Meters Maximum (C)
# - T2M_MIN         MERRA-2 Temperature at 2 Meters Minimum (C)
# - QV2M            MERRA-2 Specific Humidity at 2 Meters (g/kg)
# - RH2M            MERRA-2 Relative Humidity at 2 Meters (%)
# - PRECTOTCORR     MERRA-2 Precipitation Corrected (mm/day)
# - PS              MERRA-2 Surface Pressure (kPa)
# - WS10M           MERRA-2 Wind Speed at 10 Meters (m/s)
# - WS10M_RANGE     MERRA-2 Wind Speed at 10 Meters Range (m/s)
# - WD10M           MERRA-2 Wind Direction at 10 Meters (Degrees)
# - WS50M           MERRA-2 Wind Speed at 50 Meters (m/s)
# - WS50M_RANGE     MERRA-2 Wind Speed at 50 Meters Range (m/s)
# - WD50M           MERR
# - ALLSKY_SFC_SW_DWN       CERES SYN1deg All Sky Surface Shortwave Downward Irradiance (kW-hr/m^2/day)
# - CLRSKY_SFC_SW_DWN       CERES SYN1deg Clear Sky Surface Shortwave Downward Irradiance (kW-hr/m^2/day)
# - ALLSKY_KT               CERES SYN1deg All Sky Insolation Clearness Index (dimensionless)
# - ALLSKY_SFC_LW_DWN       CERES SYN1deg All Sky Surface Longwave Downward Irradiance (W/m^2)
# - ALLSKY_SFC_PAR_TOT      CERES SYN1deg All Sky Surface PAR Total (W/m^2)
# - CLRSKY_SFC_PAR_TOT      CERES SYN1deg Clear Sky Surface PAR Total (W/m^2)
# - ALLSKY_SFC_UVA          CERES SYN1deg All Sky Surface UVA Irradiance (W/m^2)
# - ALLSKY_SFC_UVB          CERES SYN1deg All Sky Surface UVB Irradiance (W/m^2)
# - ALLSKY_SFC_UV_INDEX     CERES SYN1deg All Sky Surface UV Index (dimensionless)
# - WS2M                    MERRA-2 Wind Speed at 2 Meters (m/s) -2

# %%
data = pd.read_csv('climate data.csv')

# %%
data.head()
# Out:
#    YEAR  MO  DY  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_SW_DWN  ALLSKY_KT  \
# 0  1990   1   1               0.92               2.98       0.21
# 1  1990   1   2               2.73               3.11       0.62
# 2  1990   1   3               2.68               3.15       0.60
# 3  1990   1   4               2.02               2.98       0.45
# 4  1990   1   5               0.50               3.15       0.11
#
#    ALLSKY_SFC_LW_DWN  ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  ALLSKY_SFC_UVA  \
# 0              320.7                19.7              -999.0          -999.0
# 1              274.9                50.9              -999.0          -999.0
# 2              280.6                50.6              -999.0          -999.0
# 3              322.5                39.6              -999.0          -999.0
# 4              315.5                11.0              -999.0          -999.0
#
#    ALLSKY_SFC_UVB  ALLSKY_SFC_UV_INDEX  WS2M
# 0          -999.0               -999.0  2.39
# ...

# %%
data2 = pd.read_csv('climate data 2.csv')

# %%
data2.head()
# Out:
#    YEAR  MO  DY   T2M  T2MDEW  T2MWET    TS  T2M_RANGE  T2M_MAX  T2M_MIN  \
# 0  1990   1   1  9.37    7.59    8.48  9.33       7.38    12.91     5.53
# 1  1990   1   2  7.61    6.53    7.07  7.02       7.61    12.25     4.64
# 2  1990   1   3  8.76    4.08    6.42  8.32      11.55    15.61     4.06
# 3  1990   1   4  8.78    4.08    6.43  8.51      10.89    15.07     4.19
# 4  1990   1   5  9.23    7.96    8.60  8.73       5.68    11.68     6.01
#
#    QV2M   RH2M  PRECTOTCORR     PS  WS10M  WS10M_RANGE   WD10M  WS50M  \
# 0  6.71  88.81         1.55  97.46   3.80         3.80  327.69   6.03
# 1  6.23  91.62         1.31  97.71   3.16         2.03  297.31   4.80
# 2  5.31  75.50         0.15  97.52   2.79         3.21  216.44   4.48
# 3  5.25  74.06         0.31  97.17   2.84         2.08  152.94   4.91
# 4  6.84  91.94         6.70  97.69   4.09         6.36  106.62   6.27
#
#    WS50M_RANGE   WD50M
# 0         2.34  327.56
# 1         1.67  297.56
# 2         6.05  216.38
# ...

# %%
# Merge the two DataFrames based on the date columns
merged_df = pd.merge(data, data2, on=['YEAR', 'MO', 'DY'])

# Print the merged DataFrame
merged_df.head()
# Out:
#    YEAR  MO  DY  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_SW_DWN  ALLSKY_KT  \
# 0  1990   1   1               0.92               2.98       0.21
# 1  1990   1   2               2.73               3.11       0.62
# 2  1990   1   3               2.68               3.15       0.60
# 3  1990   1   4               2.02               2.98       0.45
# 4  1990   1   5               0.50               3.15       0.11
#
#    ALLSKY_SFC_LW_DWN  ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  ALLSKY_SFC_UVA  \
# 0              320.7                19.7              -999.0          -999.0
# 1              274.9                50.9              -999.0          -999.0
# 2              280.6                50.6              -999.0          -999.0
# 3              322.5                39.6              -999.0          -999.0
# 4              315.5                11.0              -999.0          -999.0
#
#    ...  QV2M   RH2M  PRECTOTCORR     PS  WS10M  WS10M_RANGE   WD10M  WS50M  \
# ...

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12536 entries, 0 to 12535
# Data columns (total 30 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   YEAR                 12536 non-null  int64
#  1   MO                   12536 non-null  int64
#  2   DY                   12536 non-null  int64
#  3   ALLSKY_SFC_SW_DWN    12536 non-null  float64
#  4   CLRSKY_SFC_SW_DWN    12536 non-null  float64
#  5   ALLSKY_KT            12536 non-null  float64
#  6   ALLSKY_SFC_LW_DWN    12536 non-null  float64
#  7   ALLSKY_SFC_PAR_TOT   12536 non-null  float64
#  8   CLRSKY_SFC_PAR_TOT   12536 non-null  float64
#  9   ALLSKY_SFC_UVA       12536 non-null  float64
#  10  ALLSKY_SFC_UVB       12536 non-null  float64
#  11  ALLSKY_SFC_UV_INDEX  12536 non-null  float64
#  12  WS2M                 12536 non-null  float64
#  13  T2M                  12536 non-null  float64
#  14  T2MDEW               12536 non-null  float64
# ...

# %%
merged_df.to_csv('climate.csv', index=False)

# %%
df= pd.read_csv('climate.csv')

# %%
df.head()
# Out:
#    YEAR  MO  DY  ALLSKY_SFC_SW_DWN  CLRSKY_SFC_SW_DWN  ALLSKY_KT  \
# 0  1990   1   1               0.92               2.98       0.21
# 1  1990   1   2               2.73               3.11       0.62
# 2  1990   1   3               2.68               3.15       0.60
# 3  1990   1   4               2.02               2.98       0.45
# 4  1990   1   5               0.50               3.15       0.11
#
#    ALLSKY_SFC_LW_DWN  ALLSKY_SFC_PAR_TOT  CLRSKY_SFC_PAR_TOT  ALLSKY_SFC_UVA  \
# 0              320.7                19.7              -999.0          -999.0
# 1              274.9                50.9              -999.0          -999.0
# 2              280.6                50.6              -999.0          -999.0
# 3              322.5                39.6              -999.0          -999.0
# 4              315.5                11.0              -999.0          -999.0
#
#    ...  QV2M   RH2M  PRECTOTCORR     PS  WS10M  WS10M_RANGE   WD10M  WS50M  \
# ...

# %%
# Create an empty dictionary to store counts for each column
counts_999 = {}

# Iterate over each column in the DataFrame
for column in merged_df.columns:
    # Count occurrences of -999 in the current column
    count_999 = (merged_df[column] == -999).sum()
    
    # Store the count in the dictionary with column name as the key
    counts_999[column] = count_999

# Display the counts of - 999 for each column
for column, count in counts_999.items():
    print(f"Column '{column}': {count} occurrences of -999")

# there an important null values in the columns CLRSKY_SFC_PAR_TOT ,  ALLSKY_SFC_UVA and ALLSKY_SFC_UVB !!!!
# Out:
# Column 'YEAR': 0 occurrences of -999
# Column 'MO': 0 occurrences of -999
# Column 'DY': 0 occurrences of -999
# Column 'ALLSKY_SFC_SW_DWN': 27 occurrences of -999
# Column 'CLRSKY_SFC_SW_DWN': 86 occurrences of -999
# Column 'ALLSKY_KT': 117 occurrences of -999
# Column 'ALLSKY_SFC_LW_DWN': 27 occurrences of -999
# Column 'ALLSKY_SFC_PAR_TOT': 117 occurrences of -999
# Column 'CLRSKY_SFC_PAR_TOT': 4135 occurrences of -999
# Column 'ALLSKY_SFC_UVA': 4135 occurrences of -999
# Column 'ALLSKY_SFC_UVB': 4135 occurrences of -999
# Column 'ALLSKY_SFC_UV_INDEX': 4227 occurrences of -999
# Column 'WS2M': 1 occurrences of -999
# Column 'T2M': 1 occurrences of -999
# Column 'T2MDEW': 1 occurrences of -999
# Column 'T2MWET': 1 occurrences of -999
# Column 'TS': 1 occurrences of -999
# Column 'T2M_RANGE': 1 occurrences of -999
# Column 'T2M_MAX': 1 occurrences of -999
# Column 'T2M_MIN': 1 occurrences of -999
# Column 'QV2M': 1 occurrences of -999
# Column 'RH2M': 1 occurrences of -999
# ...

# %%
# Create a new column 'Date' by merging 'YEAR', 'MO', and 'DY' with '/' separator
df['Date'] = df['YEAR'].astype(str) + '/' + df['MO'].astype(str) + '/' + df['DY'].astype(str)

# Convert the concatenated date strings to datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m/%d')

# %%
# List of original date columns to be removed
date_columns = ['YEAR', 'MO', 'DY']

# Drop the original date columns from the DataFrame
df.drop(date_columns, axis=1, inplace=True)

# save the data
df.to_csv('climate.csv', index=False)

# %%
import pandas as pd 
df= pd.read_csv('climate.csv')

# %%
df = pd.DataFrame(df)

# Specify columns for the bar chart
columns_to_plot = ['ALLSKY_SFC_SW_DWN','CLRSKY_SFC_SW_DWN','ALLSKY_KT', 'ALLSKY_SFC_LW_DWN',  'ALLSKY_SFC_PAR_TOT', 'CLRSKY_SFC_PAR_TOT', 'ALLSKY_SFC_UVA']

# Subset the DataFrame to include only the specified columns
subset_df = df[columns_to_plot]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Filter the DataFrame to exclude rows with negative values in specified columns
filtered_df = df[(df['T2MDEW'] >= 0) & 
                 (df['T2MWET'] >= 0) & 
                 (df['TS'] >= 0) & 
                 (df['T2M_RANGE'] >= 0) & 
                 (df['T2M_MAX'] >= 0) & 
                 (df['T2M_MIN'] >= 0)]

# Plotting the meteorological variables over time
plt.figure(figsize=(13, 9))  # Set figure size

# Plot each variable against the 'Date'
plt.plot(filtered_df['Date'], filtered_df['T2MDEW'], label='T2MDEW')
plt.plot(filtered_df['Date'], filtered_df['T2MWET'], label='T2MWET')
plt.plot(filtered_df['Date'], filtered_df['TS'], label='TS')
plt.plot(filtered_df['Date'], filtered_df['T2M_RANGE'], label='T2M_RANGE')
plt.plot(filtered_df['Date'], filtered_df['T2M_MAX'], label='T2M_MAX')
plt.plot(filtered_df['Date'], filtered_df['T2M_MIN'], label='T2M_MIN')

# Customize plot attributes
plt.title('Meteorological Variables Over Jendouba ')
plt.xlabel('Date')
plt.ylabel('Value')
plt.legend()  # Show legend with variable names
plt.grid(True)  # Show grid

# Format x-axis tick labels to display only the years
plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y'))
plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.YearLocator())

# Rotate x-axis tick labels for better readability (optional)
plt.xticks(rotation=45)

# Show plot
plt.show()

# %% [markdown]
# If the meteorological variable values (e.g., `T2MDEW`, `T2MWET`, `TS`, `T2M_RANGE`, `T2M_MAX`, `T2M_MIN`) consistently fall within the range of 0 to 40 degrees Celsius over all the years, it indicates relatively moderate and favorable environmental conditions within that temperature range.
#
# 1. **Moderate Temperature Range**:
#    - The temperature values being consistently between 0 and 40 degrees Celsius suggest a moderate climate or environmental conditions.
#    - This range is generally comfortable for various activities and is within a range where many terrestrial processes operate efficiently.
#
# 2. **Seasonal Variations**:
#    - The variations within this temperature range over the years could reflect seasonal changes typical for the location.
#    - For example, temperatures might fluctuate within this range throughout the year due to seasonal transitions (e.g., summer to winter) or climatic patterns.
#
# 3. **Suitability for Agriculture**:
#    - Moderate temperature conditions (0-40°C) are generally conducive for agricultural activities.
#    - Crops and plants typically thrive within this temperature range, assuming other environmental factors such as water availability and sunlight are adequate.
#
# 4. **Comfortable Environmental Conditions**:
#    - These temperature values indicate relatively comfortable conditions for human activities and habitation.
#    - They suggest a climate that is generally not extreme in terms of heat or cold.
#
# 5. **Potential Impacts on Ecosystems**:
#    - The consistent temperature range may influence local ecosystems and biodiversity.
#    - Ecosystems adapted to these temperature conditions may exhibit stable patterns of growth and adaptation.
#
# 6. **Monitoring for Changes**:
#    - Monitoring temperature trends within this range over time is important for detecting any shifts or deviations.
#    - Sustained changes in temperature patterns could indicate broader climate shifts or local environmental changes.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'df' is your DataFrame containing the meteorological features

def plot_category(df, category, variables, ylabel, filter_value=-999):
    """
    Plot variables of a specified category from the DataFrame, excluding negative and specified filter values.
    
    Parameters:
        df (DataFrame): DataFrame containing the meteorological features.
        category (str): Category name for the plot title.
        variables (list): List of variable names to plot from the DataFrame.
        ylabel (str): Label for the y-axis of the plot.
        filter_value (numeric): Value to exclude from plotting (default: -999).
    """
    # Copy the DataFrame to avoid modifying the original
    filtered_df = df.copy()
    
    # Exclude rows with negative or specified filter values in the specified variables
    for variable in variables:
        filtered_df = filtered_df[(filtered_df[variable] > 0) & (filtered_df[variable] != filter_value)]
    
    # Set figure size
    plt.figure(figsize=(13, 9))
    
    # Plot each variable against the 'Date'
    for variable in variables:
        plt.plot(filtered_df['Date'], filtered_df[variable], label=variable)
    
    # Customize plot attributes
    plt.title(f'{category} Over Time of Jendouba')
    plt.xlabel('Date')
    plt.ylabel(ylabel)
    plt.legend()
    plt.grid(True)
    
    # Format x-axis tick labels to display only the years
    plt.gca().xaxis.set_major_formatter(plt.matplotlib.dates.DateFormatter('%Y'))
    plt.gca().xaxis.set_major_locator(plt.matplotlib.dates.YearLocator())
    
    # Rotate x-axis tick labels for better readability (optional)
    plt.xticks(rotation=45)
    
    # Show plot
    plt.show()

# Define categories and corresponding variables
categories = {
    'Radiation Variables': ['ALLSKY_SFC_SW_DWN', 'CLRSKY_SFC_SW_DWN', 'ALLSKY_KT', 
                            'ALLSKY_SFC_LW_DWN', 'ALLSKY_SFC_PAR_TOT', 'CLRSKY_SFC_PAR_TOT',
                            'ALLSKY_SFC_UVA', 'ALLSKY_SFC_UVB', 'ALLSKY_SFC_UV_INDEX'],
    'Wind Speed Variables': ['WS10M', 'WS10M_RANGE', 'WD10M', 'WS50M', 'WS50M_RANGE', 'WD50M', 'WS2M'],
    'Meteorological Variables': ['T2M', 'T2MDEW', 'T2MWET', 'TS', 'T2M_RANGE', 'T2M_MAX', 'T2M_MIN',
                                 'QV2M', 'RH2M', 'PS', 'PRECTOTCORR'],
    'Precipitation Variables': ['PRECTOTCORR'],  
    'Humidity Variables': ['QV2M', 'RH2M'], 
    'Temperature Extremes': ['T2M_MAX', 'T2M_MIN', 'T2M_RANGE'],
    'Surface Pressure': ['PS'],
    'Insolation and UV Index': ['ALLSKY_SFC_UVA', 'ALLSKY_SFC_UVB', 'ALLSKY_SFC_UV_INDEX'],
    'Wind Direction Variables': ['WD10M', 'WD50M']  
}

# Plot each category of meteorological variables with filtering
for category, variables in categories.items():
    plot_category(df, category, variables, ylabel='Value', filter_value=-999)

# %% [markdown]
# # III. Greenhouse Gases:

# %%
import pandas as pd 
ozone = pd.read_csv('Monthly Air Column Concentration of Ozone.csv')
co2 = pd.read_csv('Monthly Tropospheric Concentration of CO2.csv')
ch4 = pd.read_csv('Monthly Lower Tropospheric Concentration of CH4.csv')
vapor = pd.read_csv('Monthly Water Vapor in the Atmosphere.csv')

# %%
ozone = pd.DataFrame(ozone)
co2 = pd.DataFrame(co2)
ch4 = pd.DataFrame(ch4)
vapor = pd.DataFrame(vapor)

# %% [markdown]
# ## Air Column Concentration of Ozone

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data 
ozone = pd.read_csv('Monthly Air Column Concentration of Ozone.csv')

# Create DataFrame
ozone = pd.DataFrame(ozone)

# Split the single column into multiple columns
ozone = ozone['DATETIME,TIME,LON,LAT,TOTAL_COLUMN_OZONE'].str.split(',', expand=True)

# %%
# Generate monthly date range
date_range = pd.date_range(start='2004-10-01', end='2023-08-01', freq='M')

# Create a new DataFrame with monthly dates
df_dates = pd.DataFrame(date_range, columns=['Date'])

# Merge original DataFrame with the date DataFrame based on index
merged_ozone = pd.concat([df_dates, ozone], axis=1)  # Concatenating along columns

# %%
merged_ozone[4] = merged_ozone[4].astype(float)

# %%
# Plotting
dates =  merged_ozone['Date']
values =  merged_ozone[4]

plt.figure(figsize=(10, 6))
plt.plot(dates, values, marker='o', linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Monthly Air Column Concentration of Ozone over Jendouba')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CO2

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data 
co2 = pd.read_csv('Monthly Tropospheric Concentration of CO2.csv')

# Create DataFrame
co2 = pd.DataFrame(co2)

# %%
co2.tail()
# Out:
#     DATETIME,TIME,LON,LAT,CO2_PPMV_UPPERTROP
# 247           "APR-2023",247,9.5,36.5,415.82
# 248          "MAY-2023",248,9.5,36.5,414.309
# 249          "JUN-2023",249,9.5,36.5,416.202
# 250          "JUL-2023",250,9.5,36.5,416.852
# 251          "AUG-2023",251,9.5,36.5,416.278

# %%
# Split the single column into multiple columns
co2 = co2['DATETIME,TIME,LON,LAT,CO2_PPMV_UPPERTROP'].str.split(',', expand=True)

# %%
# Generate monthly date range
date_range = pd.date_range(start='2002-09-01', end='2022-09-01', freq='M')

# Create a new DataFrame with monthly dates
df_dates = pd.DataFrame(date_range, columns=['Date'])

# Merge original DataFrame with the date DataFrame based on index
merged_co2 = pd.concat([df_dates, co2], axis=1)  # Concatenating along columns

merged_co2[4] = merged_co2[4].astype(float)

# %%
# Plotting
dates =  merged_co2['Date']
values =  merged_co2[4]

plt.figure(figsize=(10, 6))
plt.plot(dates, values, marker='o', linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Monthly Tropospheric Concentration of CO2 over Jendouba')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## CH4

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#read the data 
ch4 = pd.read_csv('Monthly Lower Tropospheric Concentration of CH4.csv')

# Create DataFrame
ch4 = pd.DataFrame(ch4)

# %%
ch4.tail()
# Out:
#    DATETIME,TIME,LON,LAT,CH4_VMR_A_
# 34       "NOV-2021",34,9,36,1.92341
# 35       "DEC-2021",35,9,36,1.90048
# 36        "JAN-2022",36,9,36,1.9127
# 37       "FEB-2022",37,9,36,1.90642
# 38       "MAR-2022",38,9,36,1.90875

# %%
# Split the single column into multiple columns
ch4 = ch4['DATETIME,TIME,LON,LAT,CH4_VMR_A_'].str.split(',', expand=True)

# %%
# Generate monthly date range
date_range = pd.date_range(start='2019-01-01', end='2022-03-01', freq='M')

# Create a new DataFrame with monthly dates
df_dates = pd.DataFrame(date_range, columns=['Date'])

# Merge original DataFrame with the date DataFrame based on index
merged_ch4 = pd.concat([df_dates, co2], axis=1)  # Concatenating along columns

merged_ch4[4] = merged_ch4[4].astype(float)

# %%
# Plotting
dates =  merged_ch4['Date']
values =  merged_ch4[4]

plt.figure(figsize=(10, 6))
plt.plot(dates, values, marker='o', linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Monthly Lower Tropospheric Concentration of CH4 over Jendouba')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Vapor

# %%
#read the data 
vapor = pd.read_csv('Monthly Water Vapor in the Atmosphere.csv')

# Create DataFrame
vapor = pd.DataFrame(vapor)

# %%
vapor.tail()
# Out:
#     DATETIME,TIME,LON,LAT,TOTVAP
# 233  "JAN-2022",233,9,36,10.2427
# 234   "MAR-2022",234,9,36,12.208
# 235    "APR-2022",235,9,36,14.27
# 236  "MAY-2022",236,9,36,15.5684
# 237  "JUN-2022",237,9,36,18.4062

# %%
# Split the single column into multiple columns
vapor = vapor['DATETIME,TIME,LON,LAT,TOTVAP'].str.split(',', expand=True)

# %%
# Generate monthly date range
date_range = pd.date_range(start='2002-09-01', end='2022-06-01', freq='M')

# Create a new DataFrame with monthly dates
df_dates = pd.DataFrame(date_range, columns=['Date'])

# Merge original DataFrame with the date DataFrame based on index
merged_vapor= pd.concat([df_dates, vapor], axis=1)  # Concatenating along columns

merged_vapor[4] = merged_vapor[4].astype(float)

# %%
# Plotting
dates =  merged_vapor['Date']
values =  merged_vapor[4]

plt.figure(figsize=(10, 6))
plt.plot(dates, values, marker='o', linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Monthly Water Vapor in the Atmosphere over Jendouba')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Perciptation

# %%
import pandas as pd

# %%
per = pd.read_csv('Monthly Average Precipitation Rate.csv')

# %%
per.tail()
# Out:
#              DATETIME,TIME,LON,LAT,PRECIP
# 534  "JUL-2023",81630,8.75,36.25,0.257679
# 535  "AUG-2023",81661,8.75,36.25,0.201229
# 536  "SEP-2023",81692,8.75,36.25,0.152262
# 537   "OCT-2023",81722,8.75,36.25,0.67052
# 538   "NOV-2023",81753,8.75,36.25,2.67346

# %%
# Create DataFrame
per = pd.DataFrame(per)

# %%
# Split the single column into multiple columns
per = per['DATETIME,TIME,LON,LAT,PRECIP'].str.split(',', expand=True)

# %%
# Generate monthly date range
date_range = pd.date_range(start='1979-01-01', end='2023-12-01', freq='M')

# Create a new DataFrame with monthly dates
df_dates = pd.DataFrame(date_range, columns=['Date'])

# Merge original DataFrame with the date DataFrame based on index
merged_per= pd.concat([df_dates, per], axis=1)  # Concatenating along columns

merged_per[4] = merged_per[4].astype(float)

# %%
# Plotting
dates =  merged_per['Date']
values =  merged_per[4]

plt.figure(figsize=(20, 12))
plt.plot(dates, values, marker='o', linestyle='-', color='b')
plt.xlabel('Date')
plt.ylabel('Value')
plt.title('Monthly Average Precipitation Rate over Jendouba')
plt.xticks(rotation=90)
plt.grid(True)
plt.tight_layout()
plt.show()
